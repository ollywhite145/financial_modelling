# %%
import pandas as pd
# %matplotlib inline

# %%
df= pd.DataFrame()
df['Values'] = [100.12, 110.5, 105.2, 106.7, 110.2, 98.5, 94.2, 91.1, 93.12, 94.02, 92.17]
df['t'] = [ i+1 for i in range(11)]
df #this could be a stock price over time maybe
# Out:
#     Values   t
# 0   100.12   1
# 1   110.50   2
# 2   105.20   3
# 3   106.70   4
# 4   110.20   5
# 5    98.50   6
# 6    94.20   7
# 7    91.10   8
# 8    93.12   9
# 9    94.02  10
# 10   92.17  11

# %%
df.plot(y = 'Values', x = 't')  #line plot is by default
# Out:
# <AxesSubplot:xlabel='t'>

# %%
df.plot.line(y = 'Values', x = 't')
# Out:
# <AxesSubplot:xlabel='t'>

# %%
df.plot.area(y = 'Values', x = 't')
# Out:
# <AxesSubplot:xlabel='t'>

# %%
df.plot.bar(y = 'Values', x = 't')
# Out:
# <AxesSubplot:xlabel='t'>

# %%
df.plot.barh(y = 'Values', x = 't')
# Out:
# <AxesSubplot:ylabel='t'>

# %%
df.plot.box(y = 'Values', x = 't')
# Out:
# <AxesSubplot:>

# %%
df.plot.density(y = 'Values', x = 't')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df.plot.hist(y = 'Values', x = 't')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.pie(y = 'Values', x = 't')
# Out:
# <AxesSubplot:ylabel='Values'>

# %%
df.plot.scatter(y = 'Values', x = 't')
# Out:
# <AxesSubplot:xlabel='t', ylabel='Values'>
